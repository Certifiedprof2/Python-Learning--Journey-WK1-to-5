# %% [markdown]
# # Python Programing - Lesson One Assignment
#
# **Student Name:** Ismaila Aminu Ainoko
# **Course:** Python Programming
# **Lesson One:** Introduction to Python
# **Date:** 7th July, 2026

# %% [markdown]
# ## Exercise 1 - Printing Text
# ##### This Exercise demonstrate the use of the 'Print()' function to display text on the screen.

# %%
print("Hello, World!")
# Out:
# Hello, World!

# %%
print("My name is Ismaila Aminu A.")
# Out:
# My name is Ismaila Aminu A.

# %%
print("I am learning Python.")
# Out:
# I am learning Python.

# %%
print("Programming is exciting!")
# Out:
# Programming is exciting!

# %% [markdown]
# ## Exercise 2 -  Multiple Print Statements
# ##### This Exercise practices printing different pieces of information using seperate 'print()' statements.

# %%
print("My favourite food is Beans with Yam")
print("My favourite Movie is BathMan")
print("My favourite sport is Football")
print("My favourite color is Blue")
# Out:
# My favourite food is Beans with Yam
# My favourite Movie is BathMan
# My favourite sport is Football
# My favourite color is Blue

# %% [markdown]
# # Exercise 3 - Python Calculator
# ##### This exercise demonstrate how python perform basic Arithmetic operations

# %%
print(15+5)
print(30-2)
print(9*8)
print(72/9)
print(18%9)
print(10//3)
print(5**2)
# Out:
# 20
# 28
# 72
# 8.0
# 0
# 3
# 25

# %% [markdown]
# # Exercise 4 - Understanding Comments
# ##### Comments help to explain what the code does.
# ##### They improve readability and makes program easy to understand

# %% [markdown]
# ### Display the programming language

# %%
print("Python")
# Out:
# Python

# %% [markdown]
# ### Display the subject

# %%
print("Programming")
# Out:
# Programming

# %% [markdown]
# ### Display the lesson Title

# %%
print("Lesson One")
# Out:
# Lesson One

# %% [markdown]
# ### Exercise 5 - Mini Challenge
# ##### This exercise combine the concept learned in this lesson by printing ext and performing calculations.

# %%
print("My name is Ismaila Aminu Ainoko")
print("My dream career is Data Scientist")
print("My Country name is Nigeria")
# Out:
# My name is Ismaila Aminu Ainoko
# My dream career is Data Scientist
# My Country name is Nigeria

# %%
print(25+75)
print(40//6)
print(8**2)
# Out:
# 100
# 6
# 64

# %% [markdown]
# ## Conclusion
#
# ##### This assignment introduced the basics of Python Programing, including the use of the'print()' function, arithmetic, arithmetic operatuons and comments.
# ##### This concept provide the foundation for writing simple Python programs.
