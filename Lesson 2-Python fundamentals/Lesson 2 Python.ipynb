# %% [markdown]
# # Python Week 1 Assignment 2
# ## Variables, Data Types, Functions, and User Input
#
# **Author:** Ismaila Aminu Ainoko
#
# **Date:** July 11, 2026
#
# ### Description
# This notebook contains practical exercises completed during Week 1 of my Python learning journey. The exercises cover:
# - Variables
# - Data Types
# - Functions
# - User Input
#
# ### Tools
# - Python 3
# - Jupyter Notebook
#
# ### Learning Outcome
# By completing this assignment, I practiced storing data in variables, working with different data types, creating simple functions, and accepting user input.

# %% [markdown]
# ### Creating Variables to store and use the information for later

# %%
name = "Ismaila Aminu Ainoko"
age = 22
country = "Nigeria"
print(name)
print(age)
print(country)
# Out:
# Ismaila Aminu Ainoko
# 22
# Nigeria

# %% [markdown]
# ### Salary Calculation

# %%
Name = "Timothy"
Basic_Salary = x = 180000
Bonus = y = 30000
Total_Salary = (x + y)
print(Name, Total_Salary)
# Out:
# Timothy 210000

# %% [markdown]
# ### User Input = how to interact with users using the input() function.

# %%
name = input("Enter your name")
print("Morning!", name)
Language = input("Favourite programming language")
print(Language)

# %% [markdown]
# ### Working with Data Types: To understand Python's built-in data types

# %%
x = 10
y = 20.2
name = "Josh"
is_valid = True

print(type(x))
print(type(y))
print(type("Josh"))
print(type(True))

# %% [markdown]
# ### Dynamic Typing: changing of Data Type using variable

# %%
x = 10
name = "Mark"
print(type(x))
print(type("Mark"))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# ##### Changing the variables

# %%
x = 10
x = "Mark"
print(type(x))
# Out:
# <class 'str'>

# %% [markdown]
# ### STUDENT INFORMATION CARD

# %%
("=========================================")
("STUDENT INFORMATION CARD")
("=========================================")

Name = input("Enter your name")
Age = input("What is your age")
Course = input("What is your course")
Country = input("Which country are you from")

print("Name:     ",    Name)
print("Age:      ",    Age)
print("Course:   ",    Course)
print(" Country: ",   Country)

("==========================================")
# Out:
# Enter your name Ismaila Aminu
# What is your age 30
# What is your course Data Science
# Which country are you from Nigeria
# Name:      Ismaila Aminu
# Age:       30
# Course:    Data Science
#  Country:  Nigeria
# '=========================================='

# %% [markdown]
# ### Data Type

# %%
x = "Age"
print(type(x))
# Out:
# <class 'str'>

# %% [markdown]
# ### Convert the user's age

# %%
x = "age"
x = 10
print(type(x))
# Out:
# <class 'int'>

# %%
Age = int(Age) 

print("\n==============================")
print("     AFTER CONVERSION")
print("==============================")
print("Age     :", Age)

print("\nNew Data Type:")
print(type(Age)) 

print("\n[CONFIRMATION]: Age successfully converted from text to an integer!")
print("==============================")
# Out:
# ...
#      AFTER CONVERSION
# ...
# Age     : 30
#
# New Data Type:
# <class 'int'>
#
# [CONFIRMATION]: Age successfully converted from text to an integer!
# ...
