# %% [markdown]
# ## Customer Registration System
# ### Your first task is to create a customer profile.

# %%
print("===================================")
print(   "Customer Registration"         )
print("====================================")

customer_name = " joseph Hamiltn"
email_address = "Joseph23@gmail.com"
phone_number = "08101456784"
country = "nigeria"
occupation = "finance"
print("Name:", customer_name )
print("Email:", email_address )
print("Phone:", phone_number )
print("country:", country )
print("Occupation:", occupation )
# Out:
# ...
# Customer Registration
# ...
# Name:  joseph Hamiltn
# Email: Joseph23@gmail.com
# Phone: 08101456784
# country: nigeria
# Occupation: finance

# %% [markdown]
# ## Question 2: Hospital Patient Record
# ### A hospital wants to display patient information before consultation

# %%
print("==============================================")
print(          "Patient Record"                      )
print("==============================================")


patient_name = "Mary Okoro"
doctor = "Dr. James Ade"
diagnosis = "Malaria"
blood_group = "O+"
hospital = "City Care Hospital"


print("Patient:", patient_name)
print("Doctor:", doctor)
print("Diagnosis:", diagnosis)
print("Blood Group:", blood_group)
print("Hospital:", hospital)
# Out:
# ...
# Patient Record
# ...
# Patient: Mary Okoro
# Doctor: Dr. James Ade
# Diagnosis: Malaria
# Blood Group: O+
# Hospital: City Care Hospital

# %% [markdown]
# ## Question 3: Customer Feedback Management System

# %%
print("==============================================" )
print("             CUSTOMER FEEDBACK REPORT          ")
print("================================================")

customer_name = " Aminu Ismaila"
product = "Center Table"
product_category = "Household"
customer_rating = "4 Star"

print("Customer Name:", customer_name)
print("Product:", product)
print("Product Category:", product_category)
print("Customer rating:", customer_rating )

print("========================================")
print("        CUSTOMER REVIEW                 ")

statement = """The product arrived on time, was easy to
install, and exceeded my expectations.
I would definitely recommend it to others."""
print(statement)

print("========================================")
feedback = "Thank you for your feedback!"
print(feedback)

print("==========================================")
# Out:
# ...
#              CUSTOMER FEEDBACK REPORT
# ...
# Customer Name:  Aminu Ismaila
# Product: Center Table
# Product Category: Household
# Customer rating: 4 Star
# ...
#         CUSTOMER REVIEW
# The product arrived on time, was easy to
# install, and exceeded my expectations.
# I would definitely recommend it to others.
# ...
# Thank you for your feedback!
# ...
