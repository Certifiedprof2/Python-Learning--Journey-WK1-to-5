# %% [markdown]
# # Week 2 Assignment 1
# ## Arithmetic and Comparison Operators in Python

# %% [markdown]
# ## Project Overview
#
# This assignment demonstrates the use of arithmetic and comparison operators in Python to solve practical business problems.
#
# The exercises simulate real-world scenarios in industries such as finance, banking, education, retail, payroll, and inventory management, where calculations and decision-making are essential.
#
# The objective is to strengthen my understanding of Python syntax while developing logical thinking and problem-solving skills through practical coding exercises.

# %% [markdown]
# ## Exercise 1: Employee payroll and Bonus eligibility
# #### Calculate the employee's total salary.

# %%
Basic_Salary = 180000
Performance_Bonus = 45000
Total_Salary = Basic_Salary + Performance_Bonus
print("Total_Salary:", Total_Salary)
# Out:
# Total_Salary: 225000

# %% [markdown]
# ### To determine an employee qualifies if the total salary is greater than or equal to ₦220,000.

# %%
Eligible_for_benefits = Total_Salary >= 220000
print("Eligible for premium benefits:", Eligible_for_benefits)
# Out:
# Eligible for premium benefits: True

# %% [markdown]
# ### Question 2: Student Performance Evaluation
# ### To calculate the total cost

# %%
Python = 72
SQL = 65
Excel = 80
Power_Bi = 75
Total_Score = Python+SQL+Excel+Power_Bi
print("Total_Score:", Total_Score)
# Out:
# Total_Score: 292

# %% [markdown]
# ### To calculate the average score

# %%
Total_Score = 292
Average_score = Total_Score / 4
print("Average_score:", Average_score)
# Out:
# Average_score: 73.0

# %% [markdown]
# ### Determine whether the student passed.
# #### student passes if the average score is greater than or equal to 70.

# %%
Average_score = 73.0
Student_performance = Average_score >= 70
print("Passed:", Student_performance)
# Out:
# Passed: True

# %% [markdown]
# ### Question 3: Inventory Management System
# #### To Calculate the remaining stock

# %%
Initial_Stock = 250
Sold = 85
Remaining_Stock = Initial_Stock - Sold
print("Remaining Stock:", Remaining_Stock)
# Out:
# Remaining Stock: 165

# %%
Remaining_Stock = 165
Reorder_Needed = Remaining_Stock < 200
print("Reorder Needed:", Reorder_Needed)
# Out:
# Reorder Needed: True

# %% [markdown]
# ### Question 4: Banking Withdrawal Checker
# #### Calculate the remaining balance after the withdrawal.

# %%
Account_balance = 520000
Withdrawal = 150000
Remaining_balance = Account_balance - Withdrawal
print("Remaining_balance:", Remaining_balance)
# Out:
# Remaining_balance: 370000

# %% [markdown]
# ### Determine whether the withdrawal can be approved.
# ##### withdrawal can only be approved if the account balance is greater than or equal to the withdrawal amount

# %%
Remaining_balance = 370000
Withdrawal_Approved = Remaining_balance >= 150000
print("Withdrawal_Approved:", Withdrawal_Approved)
# Out:
# Withdrawal_Approved: True

# %% [markdown]
# ## Bonus: Smart Shopping Discount Calculator
# ### Calculate the total purchase amount.

# %%
Laptop_Bag = 18500
Wireless_Mouse = 12000
Keyboard = 24500
USB_Drive = 5000
Total_purchase = Laptop_Bag + Wireless_Mouse + Keyboard + USB_Drive
print("Total_purchase:", Total_purchase)
# Out:
# Total_purchase: 60000

# %% [markdown]
# ### If the total purchase is greater than or equal to ₦50,000, the customer qualifies for a 10% discount.

# %%
Total_purchase = 60000
Discount_qualified = Total_purchase >= 50000
print("Discount_qualified", Discount_qualified)
# Out:
# Discount_qualified True

# %% [markdown]
# ### to calculate the discount amount

# %%
Total_purchase = 60000
Discount = 0.10
Discount_Amount = Total_purchase * Discount
print("Discount_Amount:", Discount_Amount)

Total_purchase = 60000
Discount_Amount = 6000
Final_Amount = Total_purchase - Discount_Amount
print("Final_Amount:", Final_Amount)
# Out:
# Discount_Amount: 6000.0
# Final_Amount: 54000
