# %% [markdown]
# ## Student Score Tracker
# ### Create a variable named score and assign it an initial value of 60.
# ### Add 15 marks for a class assignment using +=.
# ### Subtract 5 marks for late submission using -=.
# ### Double the score as part of a special bonus using *=.
# ### Print the final score.

# %%
Score = 60
Score += 15
Score -= 5
Score *= 2
print(Score)
# Out:
# 140

# %% [markdown]
# ### Bonus challenge (using input())

# %%
Score = int(input( "Final score:"))
Score = 60
Score += 15
Score -= 5
Score *= 2
# Out:
# Final score: 140

# %% [markdown]
# ## Question 2: Digital Wallet Simulator

# %%
Balance = 25000

Balance += 8500
Balance -= 4200
Balance /= 3
print(Balance)
print(type(Balance))
# Out:
# 9766.666666666666
# <class 'float'>

# %% [markdown]
# ## Bonus Challenge: Allow the user to enter the deposit and withdrawal amounts using the input() function.

# %%
Balance = 25000

Balance += 8500
Balance -= 4200
Balance /= 3
Balance = int(input("Deposit:" ))
Balance = int(input("Withdraw:" ))
# Out:
# Deposit: 8500
# Withdraw: 4200

# %% [markdown]
# ## Question 3: Inventory Management System

# %%
stock = 150

stock -= 28
stock += 75
stock //= 12
print(stock)
# Out:
# 16

# %% [markdown]
# ## Bonus Challenge

# %%
stock = 150

stock -= 28
stock += 75
stock //= 12
stock %= 8

stock = int(input("initial stock:"))
stock = int(input("Remaining stock after sale:" ))
stock = int(input("Updated stock after restocking:" ))
stock = int(input("Number of full cartons:" ))
stock = int(input("Remaining loose item:"))
# Out:
# initial stock: 150
# Remaining stock after sale: 28
# Updated stock after restocking: 75
# Number of full cartons: 12
# Remaining loose item: 8
